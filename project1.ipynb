# %% [markdown]
# #  Project main objective is to find relationship between price and mileage  of the car aunctioned on USA

# %%
#First we import various libraries for the easiness of the project
import pandas as pd # it allows to modify the data freely
import numpy as np #mathematical calculation like converting the given data to matrix
import matplotlib.pyplot as plt #it allows for data visualization like creating graph
# %matplotlib inline
import seaborn as sns #for data visualtization

# %%
#for reading the data file of the project
df=pd.read_csv('vehiclesForProject.csv')

# %%
df.head(150)#this code gives the data
# Out:
#       id  price      brand    model  year  mileage country
# 0      1   2899       ford       se  2011   190552     usa
# 1      2   5350      dodge      mpv  2018    39590     usa
# 2      3  25000       ford     door  2014    64146     usa
# 3      4  27700  chevrolet     1500  2018     6654     usa
# 4      5   5700      dodge      mpv  2018    45561     usa
# ..   ...    ...        ...      ...   ...      ...     ...
# 145  146   6800      dodge    doors  2018    36767     usa
# 146  147  33300   cadillac      esv  2015    57932     usa
# 147  148  10780      dodge      mpv  2018    19420     usa
# 148  149   6700       ford  cutaway  2014   204155     usa
# 149  150  20000  chevrolet     1500  2016    93493     usa
#
# [150 rows x 7 columns]

# %%
#to find the mean, median, mode or for the statistical view of the code
df.describe()
# Out:
#                id         price         year        mileage
# count  150.000000    150.000000   150.000000     150.000000
# mean    75.500000  16895.806667  2016.386667   45202.526667
# std     43.445368  10920.865792     4.331540   35055.585829
# min      1.000000      0.000000  1973.000000    2430.000000
# 25%     38.250000   7327.500000  2017.000000   28106.750000
# 50%     75.500000  14950.000000  2017.000000   34810.000000
# 75%    112.750000  23400.000000  2018.000000   46631.000000
# max    150.000000  55000.000000  2020.000000  204155.000000

# %% [markdown]
# # US Cars'data scraped from AUCTION EXPORT.com.
# ### Price
# >* Maximum is 55000
# >* Average is 16895
# >* Minimum is 0
# ### Mileage
# >* Maximum is 204155
# >* Average is 16895
# >* Minimum is 0

# %%
df.info()#to check the information of the given dataset such as total memory, total string values and total integer values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       150 non-null    int64
#  1   price    150 non-null    int64
#  2   brand    150 non-null    object
#  3   model    150 non-null    object
#  4   year     150 non-null    int64
#  5   mileage  150 non-null    int64
#  6   country  150 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 8.3+ KB

# %% [markdown]
# # notes from data.info()
# * 0 does not count as null value
# * int64 means the the data has total space of 64 bytes
# * in dtype feature, we have to convert the string data given by user to 0 and 1 so that the machine can understand
# * total memory of 8.3+kb

# %% [markdown]
# ### now we use the mean manupulation method so that we can replace null values with mean value
# #### Mean manupulation method refers to the method in which we replace the null value with mean value

# %%
#inspecting the null values in the dataset
#print(df.isnull().values.sum())
print(df.isnull().values.sum())

#replace the ' 's with NaN
df = df.replace(" ",np.NaN)
#df=df.replace(" ",np.NaN)
#impute the missing values with mean imputation
df=df.fillna(df.mean())
#count the numbers again for verification
print(df.isnull().values.sum())
# Out:
# 0
# 0
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12924\3460512506.py:9: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
#seaborn histogram
sns.displot(data=df, x="price", kind="hist")
#add labels
plt.title('Price View according to the count of the car')
plt.xlabel('Price')
plt.ylabel('Count')
# Out:
# Text(13.819444444444445, 0.5, 'Count')

# %% [markdown]
# # Interpretation
#
# >* Here price of the car data is shown in x axis whereas the count is shown in y axis.
# >* Cars of around 10k to 20k is found be sold maximum whereas cars around 40k to 50k are found to be sold minumum according to the graph.

# %%
sns.displot(data=df, x="mileage",kind="kde")
#sns.displot(data=df, x="absences", kind="hist")

plt.title('Mileage given by car to the count')
plt.xlabel("Mileage")
plt.ylabel("count")

#show the graph
plt.show()

# %% [markdown]
# # Interpretation
#
# >* Here milrage given by the car data is shown in x axis whereas the count is shown in y axis.
# >* Cars which gives mileage about 50k to 100k is found maximum whereas cars which gives mileage around 200k to 250k are found minumum according to the graph.

# %%
sns.barplot(data=df, x="year", y="price")
plt.title('Cars of various price in the following years ')
plt.show()

# %% [markdown]
# # Intrepretation of the graph
# >* Most expensive car is found to be of 1973 with the price value of 30k and the least expensive arer found to be of 2010 which has the price value about 5k

# %%
sns.barplot(data=df, x="year", y="mileage")
plt.title('Comparing cars mileage accorinding to the manufactured years')
plt.show()

# %% [markdown]
# # Intrepretation
# >* Cars manufactured at 2011 gives the most mileage which is around 175k to 200k but the cars manufactured at 2020 gives the least mileage which is below 25k.

# %%
sns.scatterplot(data=df, x="price", y="mileage")
plt.title('Scatarplot of price vs mileage')
plt.xlabel("price")
plt.ylabel("mileage")
# Out:
# Text(0, 0.5, 'mileage')

# %% [markdown]
# # Intrepretation of the graph
# >* The given chart is the scatarplot comparing price of the aunctioned vehicle with the mileage of the car.
# >* The chart shows that the car which has the price of 10k dollars provides the highest mileage whereas the car of around 40k provides the lowest mileage.

# %%
sns.lineplot(data=df,x="year",y="price")
plt.title("Linegraph of year vs price")
# Out:
# Text(0.5, 1.0, 'Linegraph of year vs price')

# %% [markdown]
# # Intrepretation of the graph
# >* The given chart is the linegraph of year vs price.
# >* The most cars are seen to be manufactured during 2010 to 2020
# >* THe given chart shows that the car manufactured before 1980 is the most expensive and the car manufactured around just above 2010 is the least expensive.

# %%
sns.lineplot(data=df,x="year",y="mileage")
plt.title("Linegraph of year vs mileage")
# Out:
# Text(0.5, 1.0, 'Linegraph of year vs mileage')

# %% [markdown]
# #

# %% [markdown]
# # Intrepretation of the graph
# >* The given chart is the linegraph of year vs price.
# >* THe given chart shows that the car manufactured around 2010 gives the most mileage whereas the cars manufactured at 2020 gives the least mileage.

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12924\2314811246.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features', size = 15)
colormap = sns.diverging_palette(10, 220, as_cmap = True)
sns.heatmap(df.corr(),
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':20 })
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12924\1626100259.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),

# %% [markdown]
# # Intrepretation of the graph
# >* The relationship between the components are shown according to the color.
# >* -0.2 means the given features are not so related whereas 1 shows that they are highly related to each other and 0.2 and above is also considered as highly related.
# >* The graph shows that price and mileage are not so related.
